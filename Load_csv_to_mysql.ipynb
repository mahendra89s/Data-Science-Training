# %%
import pandas as pd
from sqlalchemy import create_engine, types

engine = create_engine('mysql://root:root@localhost/TrailDB')

df = pd.read_csv("car_crashes.csv",sep=',',quotechar='\'',encoding='utf8') 
df.to_sql('Car_crash',con=engine,index=False,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_17872/3003635409.py in <module>
#       2 from sqlalchemy import create_engine, types
#       3
# ----> 4 engine = create_engine('mysql://root:root@localhost/TrailDB')
#       5
#       6 df = pd.read_csv("car_crashes.csv",sep=',',quotechar='\'',encoding='utf8')
#
# <string> in create_engine(url, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     546             if k in kwargs:
#     547                 dbapi_args[k] = pop_kwarg(k)
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine, types

engine = create_engine('mysql://root:root@localhost/TrailDB')

df = pd.read_csv("car_crashes.csv",sep=',',quotechar='\'',encoding='utf8') 
df.to_sql('Car_crash',con=engine,index=False,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_20251/1515506650.py in <module>
#       2 from sqlalchemy import create_engine, types
#       3
# ----> 4 engine = create_engine('mysql://root:root@localhost/TrailDB')
#       5
#       6 df = pd.read_csv("car_crashes.csv",sep=',',quotechar='\'',encoding='utf8')
#
# <string> in create_engine(url, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     546             if k in kwargs:
#     547                 dbapi_args[k] = pop_kwarg(k)
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine, types

engine = create_engine('mysql+pymysql://root:root@127.0.0.1:3306/TrailDB?unix_socket=/var/run/mysqld/mysqld.sock')

df = pd.read_csv("car_crashes.csv",sep=',',quotechar='\'',encoding='utf8') 
df.to_sql('Car_crash',con=engine,index=False,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine, types

engine = create_engine('mysql+pymysql://root:@localhost/TrailDB?unix_socket=/var/run/mysqld/mysqld.sock')

df = pd.read_csv("car_crashes.csv",sep=',',quotechar='\'',encoding='utf8') 
df.to_sql('Car_crash',con=engine,index=False,if_exists='append')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20251/1071123522.py in <module>
# ----> 1 df.column
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df.column()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20251/1114064248.py in <module>
# ----> 1 df.column()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
list(df)[0]
# Out:
# 'total'

# %%
for i in range(0,len(list(df))):
    transformed_header = list(df)[i].capitalize().replace('_',' ')
    
    df.rename(columns={list(df)[i]:transformed_header}, inplace = True)

# %%
df
# Out:
#     Total  Speeding  Alcohol  Not distracted  No previous  Ins premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.round(2)
# Out:
#     Total  Speeding  Alcohol  Not distracted  No previous  Ins premium  \
# 0    18.8      7.33     5.64           18.05        15.04       784.55
# 1    18.1      7.42     4.53           16.29        17.01      1053.48
# 2    18.6      6.51     5.21           15.62        17.86       899.47
# 3    22.4      4.03     5.82           21.06        21.28       827.34
# 4    12.0      4.20     3.36           10.92        10.68       878.41
# 5    13.6      5.03     3.81           10.74        12.92       835.50
# 6    10.8      4.97     3.89            9.40         8.86      1068.73
# 7    16.2      6.16     4.86           14.09        16.04      1137.87
# 8     5.9      2.01     1.59            5.90         5.90      1273.89
# 9    17.9      3.76     5.19           16.47        16.83      1160.13
# 10   15.6      2.96     3.90           14.82        14.51       913.15
# 11   17.5      9.45     7.18           14.35        15.22       861.18
# ...

# %%
df = df.round(2)

# %%
df
# Out:
#     Total  Speeding  Alcohol  Not distracted  No previous  Ins premium  \
# 0    18.8      7.33     5.64           18.05        15.04       784.55
# 1    18.1      7.42     4.53           16.29        17.01      1053.48
# 2    18.6      6.51     5.21           15.62        17.86       899.47
# 3    22.4      4.03     5.82           21.06        21.28       827.34
# 4    12.0      4.20     3.36           10.92        10.68       878.41
# 5    13.6      5.03     3.81           10.74        12.92       835.50
# 6    10.8      4.97     3.89            9.40         8.86      1068.73
# 7    16.2      6.16     4.86           14.09        16.04      1137.87
# 8     5.9      2.01     1.59            5.90         5.90      1273.89
# 9    17.9      3.76     5.19           16.47        16.83      1160.13
# 10   15.6      2.96     3.90           14.82        14.51       913.15
# 11   17.5      9.45     7.18           14.35        15.22       861.18
# ...

# %%
df.to_sql('Car_crash',con=engine,index=False,if_exists='append')

# %%
dt = df
for x in dt.index:
    if(dt.loc[x,'Speeding']< 4 or dt.loc[x,'Alcohol'] < 4):
        dt.drop(x,inplace=True)

# %%
dt
# Out:
#     Total  Speeding  Alcohol  Not distracted  No previous  Ins premium  \
# 0    18.8      7.33     5.64           18.05        15.04       784.55
# 2    18.6      6.51     5.21           15.62        17.86       899.47
# 11   17.5      9.45     7.18           14.35        15.22       861.18
# 18   20.5      7.18     6.76           14.96        20.09      1281.55
# 25   16.1      6.92     5.47           14.81        13.52       790.32
# 26   21.4      8.35     9.42           17.98        18.19       816.21
# 33   16.8      6.55     5.21           15.79        13.61       708.24
# 34   23.9      5.50    10.04           23.66        20.55       688.75
# 36   19.9      6.37     5.77           18.31        18.71       881.51
# 38   18.2      9.10     5.64           17.47        16.02       905.99
# 40   23.9      9.08     9.80           22.94        19.36       858.97
# 41   19.4      6.01     6.40           19.01        16.68       669.31
# ...

# %%
dt.to_sql('Car_crash',con=engine,index=False,if_exists='append')
